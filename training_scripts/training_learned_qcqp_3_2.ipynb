# %%
# %matplotlib widget

import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_theme()

import torch 
import torch.nn as nn 
import torch.optim as optim

# import torch_optimizer as optim_custom
from torch.utils.data import Dataset, DataLoader
from utils.bernstein_torch import bernstein_coeff_order10_new
# import scipy.io as sio

# from models.mlp_qp_vis_aware_2 import MLP, vis_aware_track_net, PointNet
# import pol_matrix_comp
# from tqdm import trange

from models.learned_optim_qcqp_3_2 import PointNet, CustomGRULayer, GRU_Hidden_State, MLP_Init, Learned_QCQP
from scipy.io import loadmat
import pol_matrix_comp

import bernstein_coeff_order10_arbitinterval
# torch.set_default_dtype(torch.float64)

# %%
t_fin = 10.0
num = 100
tot_time = np.linspace(0, t_fin, num)
tot_time_copy = tot_time.reshape(num, 1)


P_np, Pdot_np, Pddot_np = pol_matrix_comp.pol_matrix_comp(tot_time_copy)
#
# P_np, Pdot_np, Pddot_np = bernstein_coeff_order10_arbitinterval.bernstein_coeff_order10_new(10, tot_time_copy[0], tot_time_copy[-1], tot_time_copy)


nvar = np.shape(P_np)[1]

P = torch.from_numpy(P_np).float()
Pdot = torch.from_numpy(Pdot_np).float()
Pddot = torch.from_numpy(Pddot_np).float()

P_diag = torch.block_diag(P, P)
Pddot_diag = torch.block_diag(Pddot, Pddot)





num_obs = 8
num_circles = 3

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
data = loadmat('./dataset/goal_reaching_dataset_4.mat')

init_state_ego = data['init_state_ego']
goal_des = data['goal_des']
closest_obs = data['closest_obs']
v_obs = data['v_obs']
y_lane_bound = data['y_lane_bound']
y_lb = y_lane_bound[:, 0]
y_ub = y_lane_bound[:, 1]
param_des = data['param_des']
dim_x_obs = data['dim_x_obs']
dim_y_obs = data['dim_y_obs']
psi_obs = data['psi_obs']

# print(np.shape(dim_x_obs))


dataset_size = np.shape(init_state_ego)[0]

inp = np.hstack(( init_state_ego, goal_des, y_lane_bound   ))

inp_mean, inp_std = inp.mean(), inp.std()


pcd_data_temp = np.hstack(( closest_obs, dim_x_obs, dim_y_obs, v_obs, psi_obs  ))

# pcd_data = closest_obs.reshape(dataset_size, 2, num_obs   )

pcd_data = pcd_data_temp.reshape(dataset_size, 6, num_obs)


# pcd_data = closest_obs.reshape(dataset_size, 2, num_obs   )

min_pcd, max_pcd = pcd_data.min(), pcd_data.max()

pcd_mean, pcd_std = pcd_data.mean(), pcd_data.std()

# %%
# Custom Dataset Loader 
class TrajDataset(Dataset):
	"""Expert Trajectory Dataset."""
	def __init__(self, inp, init_state_ego, pcd_data, param_des, closest_obs, y_lane_bound, goal_des, psi_obs, dim_x_obs, dim_y_obs):
		
		# State Data
		self.inp = inp
  
		self.init_state_ego = init_state_ego
		
		# PCD Data
		self.pcd_data = pcd_data
		
		# Expert Coeff
		self.param_des = param_des
		
		self.closest_obs = closest_obs
  
		self.y_lane_bound = y_lane_bound
		self.goal_des = goal_des
		self.psi_obs = psi_obs 
		self.dim_x_obs = dim_x_obs 
		self.dim_y_obs = dim_y_obs

	
	def __len__(self):
		return len(self.inp)    
			
	def __getitem__(self, idx):
		
		# Inputs
		inp = self.inp[idx]
		init_state_ego = self.inp[idx]

		pcd_data = self.pcd_data[idx]
		
		# Outputs
		param_des = self.param_des[idx]
		
		closest_obs = self.closest_obs[idx]
  
		y_lane_bound = self.y_lane_bound[idx]
		goal_des = self.goal_des[idx]
		dim_x_obs = self.dim_x_obs[idx]
		dim_y_obs = self.dim_y_obs[idx] 
		psi_obs = self.psi_obs[idx]

  
  
		return torch.tensor(inp).float(), torch.tensor(init_state_ego).float(), torch.tensor(pcd_data).float(), torch.tensor(param_des).float(), torch.tensor(closest_obs).float(), torch.tensor(y_lane_bound).float(), torch.tensor(goal_des).float(),\
			   torch.tensor(psi_obs).float(), torch.tensor(dim_x_obs).float(), torch.tensor(dim_y_obs).float()		

# Batch Size - 3k or 4k
batch_size = 128

# pcd_data = pcd_data.reshape(data_set_size, 2, 200)

# Using PyTorch Dataloader
train_dataset = TrajDataset(inp, init_state_ego, pcd_data, param_des, closest_obs, y_lane_bound, goal_des, psi_obs, dim_x_obs, dim_y_obs)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0, drop_last=True)

# %%
# Differentiable Layer
num_batch = train_loader.batch_size

P = P.to(device) 
Pdot = Pdot.to(device)
P_diag = P_diag.to(device)
Pddot_diag = Pddot_diag.to(device)

# PointNet
pcd_features = 40
point_net = PointNet(inp_channel=6, emb_dims=1024, output_channels=pcd_features)


mlp_init_inp_dim = np.shape(inp)[1]+pcd_features
mlp_init_hidden_dim = 256
# mlp_init_out_dim = (2*nvar)**2+2*nvar+2*nvar
mlp_init_out_dim = 2*nvar+2*num+2*(num_obs*num_circles*num+2*num)


#########################33

gru_input_size_s = 6*num
gru_hidden_size_s = 512
gru_output_size_s = 2*num
gru_context_s = CustomGRULayer(gru_input_size_s, gru_hidden_size_s, gru_output_size_s)

gru_input_size_lamda = 6*nvar
gru_hidden_size_lamda = 512
gru_output_size_lamda = 2*nvar
gru_context_lamda = CustomGRULayer(gru_input_size_lamda, gru_hidden_size_lamda, gru_output_size_lamda)

gru_input_size_alpha = 3*((num_obs*num_circles*num+2*num))
gru_hidden_size_alpha = 512
gru_output_size_alpha = num_obs*num_circles*num+2*num
gru_context_alpha = CustomGRULayer(gru_input_size_alpha, gru_hidden_size_alpha, gru_output_size_alpha)


gru_input_size_d = 3*((num_obs*num_circles*num+2*num))
gru_hidden_size_d = 512
gru_output_size_d = num_obs*num_circles*num+2*num
gru_context_d = CustomGRULayer(gru_input_size_d, gru_hidden_size_d, gru_output_size_d)


input_hidden_state_init_s = pcd_features+np.shape(inp)[1]
mid_hidden_state_init_s = 512
out_hidden_state_init_s = gru_hidden_size_s 
gru_init_s  =  GRU_Hidden_State(input_hidden_state_init_s, mid_hidden_state_init_s, out_hidden_state_init_s)


input_hidden_state_init_lamda = pcd_features+np.shape(inp)[1]
mid_hidden_state_init_lamda = 512
out_hidden_state_init_lamda = gru_hidden_size_lamda
gru_init_lamda  =  GRU_Hidden_State(input_hidden_state_init_lamda, mid_hidden_state_init_lamda, out_hidden_state_init_lamda)


input_hidden_state_init_alpha = pcd_features+np.shape(inp)[1]
mid_hidden_state_init_alpha = 512
out_hidden_state_init_alpha = gru_hidden_size_alpha
gru_init_alpha  =  GRU_Hidden_State(input_hidden_state_init_alpha, mid_hidden_state_init_alpha, out_hidden_state_init_alpha)


input_hidden_state_init_d = pcd_features+np.shape(inp)[1]
mid_hidden_state_init_d = 512
out_hidden_state_init_d = gru_hidden_size_d 
gru_init_d  =  GRU_Hidden_State(input_hidden_state_init_d, mid_hidden_state_init_d, out_hidden_state_init_d)

mlp_init = MLP_Init(mlp_init_inp_dim, mlp_init_hidden_dim, mlp_init_out_dim  )


model = Learned_QCQP(num_obs, t_fin, P, Pdot, Pddot, point_net, num_batch, min_pcd, max_pcd, inp_mean, inp_std, gru_context_alpha, gru_init_alpha, gru_context_d, gru_init_d, gru_context_s, gru_init_s, gru_context_lamda, gru_init_lamda,  mlp_init).to(device)
model.load_state_dict(torch.load('./weights/opt_surrogate_obs_avoidance_gru_new.pth'))
# Out:
# <All keys matched successfully>

# %%
epochs = 1500
step = 0 
beta = 1.0 # 3.5

optimizer = optim.AdamW(model.parameters(), lr = 1e-4, weight_decay=6e-5)
# optimizer = optim.RMSprop(model.parameters(), lr = 1e-3, weight_decay=6e-5)

# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size = 100, gamma = 0.1)

avg_train_loss, avg_loss_primal, avg_fixed_point_loss = [], [], []
model.train()
for epoch in range(epochs):
	
	# Train Loop
	losses_train, aug_losses_primal, aug_losses_fixed_point = [], [], []
	
	for (inp, init_state_ego, pcd_data, param_des, closest_obs, y_lane_bound, goal_des, psi_obs, dim_x_obs, dim_y_obs) in train_loader:
		
		# Input and Output 
  
		################################################################################################

		# print(goal_des[0])
		# print(y_lb[0], y_ub[0])

  
		inp = inp.to(device)
		init_state_ego = init_state_ego.to(device)
		param_des = param_des.to(device)

		pcd_data = pcd_data.to(device)
		closest_obs = closest_obs.to(device)
		y_lane_bound = y_lane_bound.to(device)
		y_lb = y_lane_bound[:, 0]
		y_ub = y_lane_bound[:, 1]
		goal_des = goal_des.to(device)
		psi_obs = psi_obs.to(device)
		dim_x_obs = dim_x_obs.to(device)
		dim_y_obs = dim_y_obs.to(device)
  
		x_obs = closest_obs[:, 0:num_obs]
		y_obs = closest_obs[:, num_obs:2*num_obs]
		
		# with torch.autograd.detect_anomaly():
  
		primal_sol, accumulated_res_primal, accumulated_res_fixed_point = model(inp, init_state_ego, param_des, pcd_data,  closest_obs, psi_obs, dim_x_obs, dim_y_obs,  y_ub, y_lb, P_diag, Pddot_diag, pcd_mean, pcd_std, goal_des)
		loss, primal_loss, fixed_point_loss = model.ss_loss(accumulated_res_primal, primal_sol, accumulated_res_fixed_point)
	
		optimizer.zero_grad()
		loss.backward()
		torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.5)
		optimizer.step()
		
		losses_train.append(loss.detach().cpu().numpy()) 
		aug_losses_primal.append(primal_loss.detach().cpu().numpy())
		aug_losses_fixed_point.append(fixed_point_loss.detach().cpu().numpy())
		# aug_losses_res.append(res_loss.detach().cpu().numpy())
		# aug_losses_steer.append(steer_loss.detach().cpu().numpy())

		
	# scale = scale*1.2	
		
	if epoch % 4 == 0:    
		print(f"Epoch: {epoch + 1}, Train Loss: {np.average(losses_train):.3f}, aug_loss_primal: {np.average(aug_losses_primal):.3f}, aug_loss_fixed_point: {np.average(aug_losses_fixed_point):.3f} ")

	step += 0.15 #0.15
	# scheduler.step()
	avg_train_loss.append(np.average(losses_train)), avg_loss_primal.append(np.average(aug_losses_primal)), avg_fixed_point_loss.append(np.average(aug_losses_fixed_point))
# Out:
# Epoch: 1, Train Loss: 3.059, aug_loss_primal: 0.271, aug_loss_fixed_point: 3.059
# Epoch: 5, Train Loss: 0.872, aug_loss_primal: 0.142, aug_loss_fixed_point: 0.872
# Epoch: 9, Train Loss: 0.873, aug_loss_primal: 0.176, aug_loss_fixed_point: 0.873
# Epoch: 13, Train Loss: 0.872, aug_loss_primal: 0.171, aug_loss_fixed_point: 0.872
# Epoch: 17, Train Loss: 0.815, aug_loss_primal: 0.161, aug_loss_fixed_point: 0.815
# Epoch: 21, Train Loss: 0.761, aug_loss_primal: 0.125, aug_loss_fixed_point: 0.761
# Epoch: 25, Train Loss: 0.872, aug_loss_primal: 0.173, aug_loss_fixed_point: 0.872
# Epoch: 29, Train Loss: 0.839, aug_loss_primal: 0.161, aug_loss_fixed_point: 0.839
# Epoch: 33, Train Loss: 0.825, aug_loss_primal: 0.163, aug_loss_fixed_point: 0.825
# Epoch: 37, Train Loss: 0.828, aug_loss_primal: 0.151, aug_loss_fixed_point: 0.828
# Epoch: 41, Train Loss: 0.805, aug_loss_primal: 0.149, aug_loss_fixed_point: 0.805
# Epoch: 45, Train Loss: 0.796, aug_loss_primal: 0.154, aug_loss_fixed_point: 0.796
# Epoch: 49, Train Loss: 0.722, aug_loss_primal: 0.147, aug_loss_fixed_point: 0.722
# Epoch: 53, Train Loss: 0.801, aug_loss_primal: 0.159, aug_loss_fixed_point: 0.801
# Epoch: 57, Train Loss: 0.818, aug_loss_primal: 0.152, aug_loss_fixed_point: 0.818
# Epoch: 61, Train Loss: 0.842, aug_loss_primal: 0.156, aug_loss_fixed_point: 0.842
# Epoch: 65, Train Loss: 0.836, aug_loss_primal: 0.161, aug_loss_fixed_point: 0.836
# Epoch: 69, Train Loss: 0.792, aug_loss_primal: 0.141, aug_loss_fixed_point: 0.792
# Epoch: 73, Train Loss: 0.807, aug_loss_primal: 0.155, aug_loss_fixed_point: 0.807
# Epoch: 77, Train Loss: 0.798, aug_loss_primal: 0.153, aug_loss_fixed_point: 0.798
# Epoch: 81, Train Loss: 0.785, aug_loss_primal: 0.155, aug_loss_fixed_point: 0.785
# Epoch: 85, Train Loss: 0.801, aug_loss_primal: 0.158, aug_loss_fixed_point: 0.801
# Epoch: 89, Train Loss: 0.789, aug_loss_primal: 0.157, aug_loss_fixed_point: 0.789
# Epoch: 93, Train Loss: 0.772, aug_loss_primal: 0.154, aug_loss_fixed_point: 0.772
# Epoch: 97, Train Loss: 0.783, aug_loss_primal: 0.147, aug_loss_fixed_point: 0.783
# Epoch: 101, Train Loss: 0.826, aug_loss_primal: 0.164, aug_loss_fixed_point: 0.826
# Epoch: 105, Train Loss: 0.806, aug_loss_primal: 0.159, aug_loss_fixed_point: 0.806
# Epoch: 109, Train Loss: 0.818, aug_loss_primal: 0.151, aug_loss_fixed_point: 0.818
# Epoch: 113, Train Loss: 0.847, aug_loss_primal: 0.153, aug_loss_fixed_point: 0.847
# Epoch: 117, Train Loss: 0.774, aug_loss_primal: 0.128, aug_loss_fixed_point: 0.774
# Epoch: 121, Train Loss: 0.807, aug_loss_primal: 0.153, aug_loss_fixed_point: 0.807
# Epoch: 125, Train Loss: 0.809, aug_loss_primal: 0.152, aug_loss_fixed_point: 0.809
# Epoch: 129, Train Loss: 0.815, aug_loss_primal: 0.152, aug_loss_fixed_point: 0.815
# Epoch: 133, Train Loss: 0.791, aug_loss_primal: 0.155, aug_loss_fixed_point: 0.791
# Epoch: 137, Train Loss: 0.796, aug_loss_primal: 0.154, aug_loss_fixed_point: 0.796
# Epoch: 141, Train Loss: 0.754, aug_loss_primal: 0.153, aug_loss_fixed_point: 0.754
# Epoch: 145, Train Loss: 0.787, aug_loss_primal: 0.135, aug_loss_fixed_point: 0.787
# Epoch: 149, Train Loss: 0.778, aug_loss_primal: 0.137, aug_loss_fixed_point: 0.778
# Epoch: 153, Train Loss: 0.790, aug_loss_primal: 0.149, aug_loss_fixed_point: 0.790
# Epoch: 157, Train Loss: 0.770, aug_loss_primal: 0.154, aug_loss_fixed_point: 0.770
# Epoch: 161, Train Loss: 0.759, aug_loss_primal: 0.131, aug_loss_fixed_point: 0.759
# Epoch: 165, Train Loss: 0.857, aug_loss_primal: 0.154, aug_loss_fixed_point: 0.857
# Epoch: 169, Train Loss: 0.824, aug_loss_primal: 0.157, aug_loss_fixed_point: 0.824
# Epoch: 173, Train Loss: 0.818, aug_loss_primal: 0.159, aug_loss_fixed_point: 0.818
# Epoch: 177, Train Loss: 0.810, aug_loss_primal: 0.141, aug_loss_fixed_point: 0.810
# Epoch: 181, Train Loss: 0.778, aug_loss_primal: 0.132, aug_loss_fixed_point: 0.778
# Epoch: 185, Train Loss: 0.761, aug_loss_primal: 0.143, aug_loss_fixed_point: 0.761
# Epoch: 189, Train Loss: 0.799, aug_loss_primal: 0.155, aug_loss_fixed_point: 0.799
# Epoch: 193, Train Loss: 0.776, aug_loss_primal: 0.155, aug_loss_fixed_point: 0.776
# Epoch: 197, Train Loss: 0.823, aug_loss_primal: 0.155, aug_loss_fixed_point: 0.823
# Epoch: 201, Train Loss: 0.789, aug_loss_primal: 0.150, aug_loss_fixed_point: 0.789
# Epoch: 205, Train Loss: 0.790, aug_loss_primal: 0.143, aug_loss_fixed_point: 0.790
# Epoch: 209, Train Loss: 0.790, aug_loss_primal: 0.149, aug_loss_fixed_point: 0.790
# Epoch: 213, Train Loss: 0.699, aug_loss_primal: 0.132, aug_loss_fixed_point: 0.699
# Epoch: 217, Train Loss: 0.787, aug_loss_primal: 0.150, aug_loss_fixed_point: 0.787
# Epoch: 221, Train Loss: 0.760, aug_loss_primal: 0.131, aug_loss_fixed_point: 0.760
# Epoch: 225, Train Loss: 0.767, aug_loss_primal: 0.150, aug_loss_fixed_point: 0.767
# Epoch: 229, Train Loss: 0.782, aug_loss_primal: 0.128, aug_loss_fixed_point: 0.782
# Epoch: 233, Train Loss: 0.761, aug_loss_primal: 0.151, aug_loss_fixed_point: 0.761
# Epoch: 237, Train Loss: 0.764, aug_loss_primal: 0.150, aug_loss_fixed_point: 0.764
# Epoch: 241, Train Loss: 0.770, aug_loss_primal: 0.154, aug_loss_fixed_point: 0.770
# Epoch: 245, Train Loss: 0.752, aug_loss_primal: 0.150, aug_loss_fixed_point: 0.752
# Epoch: 249, Train Loss: 0.739, aug_loss_primal: 0.130, aug_loss_fixed_point: 0.739
# Epoch: 253, Train Loss: 0.732, aug_loss_primal: 0.147, aug_loss_fixed_point: 0.732
# Epoch: 257, Train Loss: 0.743, aug_loss_primal: 0.145, aug_loss_fixed_point: 0.743
# Epoch: 261, Train Loss: 0.771, aug_loss_primal: 0.153, aug_loss_fixed_point: 0.771
# Epoch: 265, Train Loss: 0.792, aug_loss_primal: 0.149, aug_loss_fixed_point: 0.792
# Epoch: 269, Train Loss: 0.810, aug_loss_primal: 0.149, aug_loss_fixed_point: 0.810
# Epoch: 273, Train Loss: 0.816, aug_loss_primal: 0.155, aug_loss_fixed_point: 0.816
# Epoch: 277, Train Loss: 0.791, aug_loss_primal: 0.152, aug_loss_fixed_point: 0.791
# Epoch: 281, Train Loss: 0.746, aug_loss_primal: 0.142, aug_loss_fixed_point: 0.746
# Epoch: 285, Train Loss: 0.737, aug_loss_primal: 0.133, aug_loss_fixed_point: 0.737
# Epoch: 289, Train Loss: 0.781, aug_loss_primal: 0.151, aug_loss_fixed_point: 0.781
# Epoch: 293, Train Loss: 0.710, aug_loss_primal: 0.139, aug_loss_fixed_point: 0.710
# Epoch: 297, Train Loss: 0.797, aug_loss_primal: 0.152, aug_loss_fixed_point: 0.797
# Epoch: 301, Train Loss: 0.763, aug_loss_primal: 0.145, aug_loss_fixed_point: 0.763
# Epoch: 305, Train Loss: 0.755, aug_loss_primal: 0.155, aug_loss_fixed_point: 0.755
# Epoch: 309, Train Loss: 0.771, aug_loss_primal: 0.149, aug_loss_fixed_point: 0.771
# Epoch: 313, Train Loss: 0.841, aug_loss_primal: 0.157, aug_loss_fixed_point: 0.841
# Epoch: 317, Train Loss: 0.736, aug_loss_primal: 0.151, aug_loss_fixed_point: 0.736
# Epoch: 321, Train Loss: 0.745, aug_loss_primal: 0.134, aug_loss_fixed_point: 0.745
# Epoch: 325, Train Loss: 0.762, aug_loss_primal: 0.146, aug_loss_fixed_point: 0.762
# Epoch: 329, Train Loss: 0.782, aug_loss_primal: 0.148, aug_loss_fixed_point: 0.782
# Epoch: 333, Train Loss: 0.768, aug_loss_primal: 0.137, aug_loss_fixed_point: 0.768
# Epoch: 337, Train Loss: 0.797, aug_loss_primal: 0.157, aug_loss_fixed_point: 0.797
# Epoch: 341, Train Loss: 0.790, aug_loss_primal: 0.154, aug_loss_fixed_point: 0.790
# Epoch: 345, Train Loss: 0.801, aug_loss_primal: 0.150, aug_loss_fixed_point: 0.801
# Epoch: 349, Train Loss: 0.753, aug_loss_primal: 0.150, aug_loss_fixed_point: 0.753
# Epoch: 353, Train Loss: 0.786, aug_loss_primal: 0.156, aug_loss_fixed_point: 0.786
# Epoch: 357, Train Loss: 0.749, aug_loss_primal: 0.151, aug_loss_fixed_point: 0.749
# Epoch: 361, Train Loss: 0.763, aug_loss_primal: 0.126, aug_loss_fixed_point: 0.763
# Epoch: 365, Train Loss: 0.770, aug_loss_primal: 0.146, aug_loss_fixed_point: 0.770
# Epoch: 369, Train Loss: 0.744, aug_loss_primal: 0.146, aug_loss_fixed_point: 0.744
# Epoch: 373, Train Loss: 0.764, aug_loss_primal: 0.150, aug_loss_fixed_point: 0.764
# Epoch: 377, Train Loss: 0.761, aug_loss_primal: 0.151, aug_loss_fixed_point: 0.761
# Epoch: 381, Train Loss: 0.675, aug_loss_primal: 0.138, aug_loss_fixed_point: 0.675
# Epoch: 385, Train Loss: 0.751, aug_loss_primal: 0.152, aug_loss_fixed_point: 0.751
# Epoch: 389, Train Loss: 0.736, aug_loss_primal: 0.142, aug_loss_fixed_point: 0.736
# Epoch: 393, Train Loss: 0.765, aug_loss_primal: 0.153, aug_loss_fixed_point: 0.765
# Epoch: 397, Train Loss: 0.752, aug_loss_primal: 0.146, aug_loss_fixed_point: 0.752
# Epoch: 401, Train Loss: 0.778, aug_loss_primal: 0.150, aug_loss_fixed_point: 0.778
# Epoch: 405, Train Loss: 0.742, aug_loss_primal: 0.140, aug_loss_fixed_point: 0.742
# Epoch: 409, Train Loss: 0.768, aug_loss_primal: 0.142, aug_loss_fixed_point: 0.768
# Epoch: 413, Train Loss: 0.734, aug_loss_primal: 0.135, aug_loss_fixed_point: 0.734
# Epoch: 417, Train Loss: 0.742, aug_loss_primal: 0.142, aug_loss_fixed_point: 0.742
# Epoch: 421, Train Loss: 0.730, aug_loss_primal: 0.147, aug_loss_fixed_point: 0.730
# Epoch: 425, Train Loss: 0.745, aug_loss_primal: 0.149, aug_loss_fixed_point: 0.745
# Epoch: 429, Train Loss: 0.768, aug_loss_primal: 0.138, aug_loss_fixed_point: 0.768
# Epoch: 433, Train Loss: 0.751, aug_loss_primal: 0.152, aug_loss_fixed_point: 0.751
# Epoch: 437, Train Loss: 0.729, aug_loss_primal: 0.145, aug_loss_fixed_point: 0.729
# Epoch: 441, Train Loss: 0.761, aug_loss_primal: 0.151, aug_loss_fixed_point: 0.761
# Epoch: 445, Train Loss: 0.746, aug_loss_primal: 0.140, aug_loss_fixed_point: 0.746
# Epoch: 449, Train Loss: 0.744, aug_loss_primal: 0.150, aug_loss_fixed_point: 0.744
# Epoch: 453, Train Loss: 0.746, aug_loss_primal: 0.143, aug_loss_fixed_point: 0.746
# Epoch: 457, Train Loss: 0.813, aug_loss_primal: 0.154, aug_loss_fixed_point: 0.813
# Epoch: 461, Train Loss: 0.751, aug_loss_primal: 0.147, aug_loss_fixed_point: 0.751
# Epoch: 465, Train Loss: 0.746, aug_loss_primal: 0.150, aug_loss_fixed_point: 0.746
# Epoch: 469, Train Loss: 0.748, aug_loss_primal: 0.149, aug_loss_fixed_point: 0.748
# Epoch: 473, Train Loss: 0.737, aug_loss_primal: 0.149, aug_loss_fixed_point: 0.737
# Epoch: 477, Train Loss: 0.737, aug_loss_primal: 0.146, aug_loss_fixed_point: 0.737
# Epoch: 481, Train Loss: 0.761, aug_loss_primal: 0.138, aug_loss_fixed_point: 0.761
# Epoch: 485, Train Loss: 0.783, aug_loss_primal: 0.150, aug_loss_fixed_point: 0.783
# Epoch: 489, Train Loss: 0.788, aug_loss_primal: 0.135, aug_loss_fixed_point: 0.788
# Epoch: 493, Train Loss: 0.725, aug_loss_primal: 0.148, aug_loss_fixed_point: 0.725
# Epoch: 497, Train Loss: 0.742, aug_loss_primal: 0.144, aug_loss_fixed_point: 0.742
# Epoch: 501, Train Loss: 0.718, aug_loss_primal: 0.127, aug_loss_fixed_point: 0.718
# Epoch: 505, Train Loss: 0.716, aug_loss_primal: 0.139, aug_loss_fixed_point: 0.716
# Epoch: 509, Train Loss: 0.693, aug_loss_primal: 0.144, aug_loss_fixed_point: 0.693
# Epoch: 513, Train Loss: 0.756, aug_loss_primal: 0.134, aug_loss_fixed_point: 0.756
# Epoch: 517, Train Loss: 0.774, aug_loss_primal: 0.143, aug_loss_fixed_point: 0.774
# Epoch: 521, Train Loss: 0.697, aug_loss_primal: 0.145, aug_loss_fixed_point: 0.697
# Epoch: 525, Train Loss: 0.756, aug_loss_primal: 0.146, aug_loss_fixed_point: 0.756
# Epoch: 529, Train Loss: 0.731, aug_loss_primal: 0.126, aug_loss_fixed_point: 0.731
# Epoch: 533, Train Loss: 0.745, aug_loss_primal: 0.122, aug_loss_fixed_point: 0.745
# Epoch: 537, Train Loss: 0.767, aug_loss_primal: 0.151, aug_loss_fixed_point: 0.767
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 17
#      12 for epoch in range(epochs):
#      13
#      14 	# Train Loop
#      15 	losses_train, aug_losses_primal, aug_losses_fixed_point = [], [], []
# ---> 17 	for (inp, init_state_ego, pcd_data, param_des, closest_obs, y_lane_bound, goal_des, psi_obs, dim_x_obs, dim_y_obs) in train_loader:
#      18
#      19 		# Input and Output
#      20
#      21 		################################################################################################
#      22
#      23 		# print(goal_des[0])
#      24 		# print(y_lb[0], y_ub[0])
#      27 		inp = inp.to(device)
#      28 		init_state_ego = init_state_ego.to(device)
#
# File ~/amith/torch_jax_env/lib/python3.12/site-packages/torch/utils/data/dataloader.py:704, in _BaseDataLoaderIter.__next__(self)
#     703 def __next__(self) -> Any:
# --> 704     with torch.autograd.profiler.record_function(self._profile_name):
#     705         if self._sampler_iter is None:
#     706             # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707             self._reset()  # type: ignore[call-arg]
#
# File ~/amith/torch_jax_env/lib/python3.12/site-packages/torch/autograd/profiler.py:757, in record_function.__exit__(self, exc_type, exc_value, traceback)
#     752     self.record = torch.ops.profiler._record_function_enter_new(
#     753         self.name, self.args
#     754     )
#     755     return self
# --> 757 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any):
#     758     if not self.run_callbacks_on_exit:
#     759         return
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), './weights/opt_surrogate_obs_avoidance_gru_new.pth')
