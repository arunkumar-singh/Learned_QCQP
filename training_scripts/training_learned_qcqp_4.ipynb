# %%
# %matplotlib widget

import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_theme()

import torch 
import torch.nn as nn 
import torch.optim as optim

# import torch_optimizer as optim_custom
from torch.utils.data import Dataset, DataLoader
from utils.bernstein_torch import bernstein_coeff_order10_new
# import scipy.io as sio

# from models.mlp_qp_vis_aware_2 import MLP, vis_aware_track_net, PointNet
# import pol_matrix_comp
# from tqdm import trange

from models.learned_optim_qcqp_4 import PointNet, CustomGRULayer, GRU_Hidden_State, MLP_Init, Learned_QCQP, MLP_Rho_Pred
from scipy.io import loadmat
import pol_matrix_comp

import bernstein_coeff_order10_arbitinterval
# torch.set_default_dtype(torch.float64)

# %%
t_fin = 10.0
num = 100
tot_time = np.linspace(0, t_fin, num)
tot_time_copy = tot_time.reshape(num, 1)


P_np, Pdot_np, Pddot_np = pol_matrix_comp.pol_matrix_comp(tot_time_copy)

# P_np, Pdot_np, Pddot_np = bernstein_coeff_order10_arbitinterval.bernstein_coeff_order10_new(10, tot_time_copy[0], tot_time_copy[-1], tot_time_copy)


nvar = np.shape(P_np)[1]

P = torch.from_numpy(P_np).float()
Pdot = torch.from_numpy(Pdot_np).float()
Pddot = torch.from_numpy(Pddot_np).float()

P_diag = torch.block_diag(P, P)
Pddot_diag = torch.block_diag(Pddot, Pddot)





num_obs = 8

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
data = loadmat('./dataset/goal_reaching_dataset_4.mat')

init_state_ego = data['init_state_ego']
goal_des = data['goal_des']
closest_obs = data['closest_obs']
v_obs = data['v_obs']
y_lane_bound = data['y_lane_bound']
y_lb = y_lane_bound[:, 0]
y_ub = y_lane_bound[:, 1]
param_des = data['param_des']
dim_x_obs = data['dim_x_obs']
dim_y_obs = data['dim_y_obs']
psi_obs = data['psi_obs']

# print(np.shape(dim_x_obs))


dataset_size = np.shape(init_state_ego)[0]

inp = np.hstack(( init_state_ego, goal_des, y_lane_bound   ))

inp_mean, inp_std = inp.mean(), inp.std()


pcd_data_temp = np.hstack(( closest_obs, dim_x_obs, dim_y_obs, v_obs, psi_obs  ))

# pcd_data = closest_obs.reshape(dataset_size, 2, num_obs   )

pcd_data = pcd_data_temp.reshape(dataset_size, 6, num_obs)


# pcd_data = closest_obs.reshape(dataset_size, 2, num_obs   )

min_pcd, max_pcd = pcd_data.min(), pcd_data.max()

pcd_mean, pcd_std = pcd_data.mean(), pcd_data.std()

# %%
# Custom Dataset Loader 
class TrajDataset(Dataset):
	"""Expert Trajectory Dataset."""
	def __init__(self, inp, init_state_ego, pcd_data, param_des, closest_obs, y_lane_bound, goal_des, psi_obs, dim_x_obs, dim_y_obs):
		
		# State Data
		self.inp = inp
  
		self.init_state_ego = init_state_ego
		
		# PCD Data
		self.pcd_data = pcd_data
		
		# Expert Coeff
		self.param_des = param_des
		
		self.closest_obs = closest_obs
  
		self.y_lane_bound = y_lane_bound
		self.goal_des = goal_des
		self.psi_obs = psi_obs 
		self.dim_x_obs = dim_x_obs 
		self.dim_y_obs = dim_y_obs

	
	def __len__(self):
		return len(self.inp)    
			
	def __getitem__(self, idx):
		
		# Inputs
		inp = self.inp[idx]
		init_state_ego = self.inp[idx]

		pcd_data = self.pcd_data[idx]
		
		# Outputs
		param_des = self.param_des[idx]
		
		closest_obs = self.closest_obs[idx]
  
		y_lane_bound = self.y_lane_bound[idx]
		goal_des = self.goal_des[idx]
		dim_x_obs = self.dim_x_obs[idx]
		dim_y_obs = self.dim_y_obs[idx] 
		psi_obs = self.psi_obs[idx]

  
  
		return torch.tensor(inp).float(), torch.tensor(init_state_ego).float(), torch.tensor(pcd_data).float(), torch.tensor(param_des).float(), torch.tensor(closest_obs).float(), torch.tensor(y_lane_bound).float(), torch.tensor(goal_des).float(),\
			   torch.tensor(psi_obs).float(), torch.tensor(dim_x_obs).float(), torch.tensor(dim_y_obs).float()		

# Batch Size - 3k or 4k
batch_size = 128

# pcd_data = pcd_data.reshape(data_set_size, 2, 200)

# Using PyTorch Dataloader
train_dataset = TrajDataset(inp, init_state_ego, pcd_data, param_des, closest_obs, y_lane_bound, goal_des, psi_obs, dim_x_obs, dim_y_obs)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0, drop_last=True)

# %%
# Differentiable Layer
num_batch = train_loader.batch_size

P = P.to(device) 
Pdot = Pdot.to(device)
P_diag = P_diag.to(device)
Pddot_diag = Pddot_diag.to(device)

# PointNet
pcd_features = 40
point_net = PointNet(inp_channel=6, emb_dims=1024, output_channels=pcd_features)


# mlp_pred_inp_dim = np.shape(inp)[1]+pcd_features
# mlp_pred_hidden_dim = 256
# mlp_pred_out_dim = 2*nvar 


# mlp_planner_inp_dim = np.shape(inp)[1]+pcd_features
# mlp_planner_out_dim = (2*nvar)**2+2*nvar
# hidden_dim = 512


mlp_init_inp_dim = np.shape(inp)[1]+pcd_features
mlp_init_hidden_dim = 256
# mlp_init_out_dim = (2*nvar)**2+2*nvar+2*nvar
mlp_init_out_dim = 4*nvar


mlp_rho_inp_dim = np.shape(inp)[1]+pcd_features
mlp_rho_hidden_dim = 256
# mlp_init_out_dim = (2*nvar)**2+2*nvar+2*nvar
mlp_rho_out_dim = 3

#########################33

gru_input_size = 6*nvar
# print(gru_input_size)
gru_hidden_size = 512
# gru_output_size = (2*nvar)**2+2*nvar
gru_output_size = 2*nvar
# gru_context_size = mlp_planner_inp_dim

gru_context = CustomGRULayer(gru_input_size, gru_hidden_size, gru_output_size)
gru_context_primal = CustomGRULayer(gru_input_size, gru_hidden_size, gru_output_size)

input_hidden_state_init = pcd_features+np.shape(inp)[1]
mid_hidden_state_init = 512
out_hidden_state_init = gru_hidden_size

gru_hidden_state_init  =  GRU_Hidden_State(input_hidden_state_init, mid_hidden_state_init, out_hidden_state_init)
gru_hidden_state_init_primal  =  GRU_Hidden_State(input_hidden_state_init, mid_hidden_state_init, out_hidden_state_init)

mlp_rho_pred = MLP_Rho_Pred(mlp_rho_inp_dim, mlp_rho_hidden_dim, mlp_rho_out_dim  )
mlp_init = MLP_Init(mlp_init_inp_dim, mlp_init_hidden_dim, mlp_init_out_dim  )


model = Learned_QCQP(num_obs, t_fin, P, Pdot, Pddot, point_net, num_batch, min_pcd, max_pcd, inp_mean, inp_std, gru_context, gru_hidden_state_init, mlp_init, gru_context_primal, gru_hidden_state_init_primal, mlp_rho_pred).to(device)

# %%
epochs = 800
step = 0 
beta = 1.0 # 3.5

optimizer = optim.AdamW(model.parameters(), lr = 2e-3, weight_decay=6e-5)
# optimizer = optim.RMSprop(model.parameters(), lr = 2e-3, weight_decay=6e-5)

scheduler = optim.lr_scheduler.StepLR(optimizer, step_size = 100, gamma = 0.1)

avg_train_loss, avg_loss_primal, avg_fixed_point_loss = [], [], []
model.train()
for epoch in range(epochs):
	
	# Train Loop
	losses_train, aug_losses_primal, aug_losses_fixed_point = [], [], []
	
	for (inp, init_state_ego, pcd_data, param_des, closest_obs, y_lane_bound, goal_des, psi_obs, dim_x_obs, dim_y_obs) in train_loader:
		
		# Input and Output 
  
		################################################################################################

		# print(goal_des[0])
		# print(y_lb[0], y_ub[0])

  
		inp = inp.to(device)
		init_state_ego = init_state_ego.to(device)
		param_des = param_des.to(device)

		pcd_data = pcd_data.to(device)
		closest_obs = closest_obs.to(device)
		y_lane_bound = y_lane_bound.to(device)
		y_lb = y_lane_bound[:, 0]
		y_ub = y_lane_bound[:, 1]
		goal_des = goal_des.to(device)
		psi_obs = psi_obs.to(device)
		dim_x_obs = dim_x_obs.to(device)
		dim_y_obs = dim_y_obs.to(device)
  
		x_obs = closest_obs[:, 0:num_obs]
		y_obs = closest_obs[:, num_obs:2*num_obs]
		
  
		primal_sol, accumulated_res_primal, accumulated_res_fixed_point = model(inp, init_state_ego, param_des, pcd_data,  closest_obs, psi_obs, dim_x_obs, dim_y_obs,  y_ub, y_lb, P_diag, Pddot_diag, pcd_mean, pcd_std, goal_des)
		loss, primal_loss, fixed_point_loss = model.ss_loss(accumulated_res_primal, primal_sol, accumulated_res_fixed_point)
	 
		optimizer.zero_grad()
		loss.backward()
		optimizer.step()
		
		losses_train.append(loss.detach().cpu().numpy()) 
		aug_losses_primal.append(primal_loss.detach().cpu().numpy())
		aug_losses_fixed_point.append(fixed_point_loss.detach().cpu().numpy())
		# aug_losses_res.append(res_loss.detach().cpu().numpy())
		# aug_losses_steer.append(steer_loss.detach().cpu().numpy())

		
	# scale = scale*1.2	
		
	if epoch % 4 == 0:    
		print(f"Epoch: {epoch + 1}, Train Loss: {np.average(losses_train):.3f}, aug_loss_primal: {np.average(aug_losses_primal):.3f}, aug_loss_fixed_point: {np.average(aug_losses_fixed_point):.3f} ")

	step += 0.15 #0.15
	scheduler.step()
	avg_train_loss.append(np.average(losses_train)), avg_loss_primal.append(np.average(aug_losses_primal)), avg_fixed_point_loss.append(np.average(aug_losses_fixed_point))
# Out:
# Epoch: 1, Train Loss: 123.584, aug_loss_primal: 1.578, aug_loss_fixed_point: 123.584
# Epoch: 5, Train Loss: 9.392, aug_loss_primal: 0.239, aug_loss_fixed_point: 9.392
# Epoch: 9, Train Loss: 5.611, aug_loss_primal: 0.142, aug_loss_fixed_point: 5.611
# Epoch: 13, Train Loss: 2.371, aug_loss_primal: 0.080, aug_loss_fixed_point: 2.371
# Epoch: 17, Train Loss: 1.310, aug_loss_primal: 0.048, aug_loss_fixed_point: 1.310
# Epoch: 21, Train Loss: 1.090, aug_loss_primal: 0.039, aug_loss_fixed_point: 1.090
# Epoch: 25, Train Loss: 0.843, aug_loss_primal: 0.030, aug_loss_fixed_point: 0.843
# Epoch: 29, Train Loss: 0.807, aug_loss_primal: 0.032, aug_loss_fixed_point: 0.807
# Epoch: 33, Train Loss: 0.694, aug_loss_primal: 0.023, aug_loss_fixed_point: 0.694
# Epoch: 37, Train Loss: 0.709, aug_loss_primal: 0.026, aug_loss_fixed_point: 0.709
# Epoch: 41, Train Loss: 0.584, aug_loss_primal: 0.020, aug_loss_fixed_point: 0.584
# Epoch: 45, Train Loss: 0.492, aug_loss_primal: 0.016, aug_loss_fixed_point: 0.492
# Epoch: 49, Train Loss: 0.534, aug_loss_primal: 0.018, aug_loss_fixed_point: 0.534
# Epoch: 53, Train Loss: 0.454, aug_loss_primal: 0.014, aug_loss_fixed_point: 0.454
# Epoch: 57, Train Loss: 0.473, aug_loss_primal: 0.013, aug_loss_fixed_point: 0.473
# Epoch: 61, Train Loss: 0.389, aug_loss_primal: 0.011, aug_loss_fixed_point: 0.389
# Epoch: 65, Train Loss: 0.379, aug_loss_primal: 0.010, aug_loss_fixed_point: 0.379
# Epoch: 69, Train Loss: 0.417, aug_loss_primal: 0.010, aug_loss_fixed_point: 0.417
# Epoch: 73, Train Loss: 0.429, aug_loss_primal: 0.011, aug_loss_fixed_point: 0.429
# Epoch: 77, Train Loss: 0.337, aug_loss_primal: 0.008, aug_loss_fixed_point: 0.337
# Epoch: 81, Train Loss: 0.358, aug_loss_primal: 0.008, aug_loss_fixed_point: 0.358
# Epoch: 85, Train Loss: 0.357, aug_loss_primal: 0.008, aug_loss_fixed_point: 0.357
# Epoch: 89, Train Loss: 0.304, aug_loss_primal: 0.006, aug_loss_fixed_point: 0.304
# Epoch: 93, Train Loss: 0.330, aug_loss_primal: 0.007, aug_loss_fixed_point: 0.330
# Epoch: 97, Train Loss: 0.314, aug_loss_primal: 0.006, aug_loss_fixed_point: 0.314
# Epoch: 101, Train Loss: 0.329, aug_loss_primal: 0.008, aug_loss_fixed_point: 0.329
# Epoch: 105, Train Loss: 0.284, aug_loss_primal: 0.005, aug_loss_fixed_point: 0.284
# Epoch: 109, Train Loss: 0.293, aug_loss_primal: 0.006, aug_loss_fixed_point: 0.293
# Epoch: 113, Train Loss: 0.258, aug_loss_primal: 0.005, aug_loss_fixed_point: 0.258
# Epoch: 117, Train Loss: 0.259, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.259
# Epoch: 121, Train Loss: 0.256, aug_loss_primal: 0.005, aug_loss_fixed_point: 0.256
# Epoch: 125, Train Loss: 0.244, aug_loss_primal: 0.005, aug_loss_fixed_point: 0.244
# Epoch: 129, Train Loss: 0.236, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.236
# Epoch: 133, Train Loss: 0.278, aug_loss_primal: 0.005, aug_loss_fixed_point: 0.278
# Epoch: 137, Train Loss: 0.272, aug_loss_primal: 0.005, aug_loss_fixed_point: 0.272
# Epoch: 141, Train Loss: 0.265, aug_loss_primal: 0.005, aug_loss_fixed_point: 0.265
# Epoch: 145, Train Loss: 0.274, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.274
# Epoch: 149, Train Loss: 0.289, aug_loss_primal: 0.005, aug_loss_fixed_point: 0.289
# Epoch: 153, Train Loss: 0.263, aug_loss_primal: 0.005, aug_loss_fixed_point: 0.263
# Epoch: 157, Train Loss: 0.258, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.258
# Epoch: 161, Train Loss: 0.251, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.251
# Epoch: 165, Train Loss: 0.249, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.249
# Epoch: 169, Train Loss: 0.232, aug_loss_primal: 0.003, aug_loss_fixed_point: 0.232
# Epoch: 173, Train Loss: 0.253, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.253
# Epoch: 177, Train Loss: 0.254, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.254
# Epoch: 181, Train Loss: 0.260, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.260
# Epoch: 185, Train Loss: 0.251, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.251
# Epoch: 189, Train Loss: 0.263, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.263
# Epoch: 193, Train Loss: 0.252, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.252
# Epoch: 197, Train Loss: 0.239, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.239
# Epoch: 201, Train Loss: 0.249, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.249
# Epoch: 205, Train Loss: 0.253, aug_loss_primal: 0.005, aug_loss_fixed_point: 0.253
# Epoch: 209, Train Loss: 0.258, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.258
# Epoch: 213, Train Loss: 0.262, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.262
# Epoch: 217, Train Loss: 0.241, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.241
# Epoch: 221, Train Loss: 0.244, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.244
# Epoch: 225, Train Loss: 0.238, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.238
# Epoch: 229, Train Loss: 0.232, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.232
# Epoch: 233, Train Loss: 0.238, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.238
# Epoch: 237, Train Loss: 0.224, aug_loss_primal: 0.003, aug_loss_fixed_point: 0.224
# Epoch: 241, Train Loss: 0.234, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.234
# Epoch: 245, Train Loss: 0.251, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.251
# Epoch: 249, Train Loss: 0.235, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.235
# Epoch: 253, Train Loss: 0.235, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.235
# Epoch: 257, Train Loss: 0.247, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.247
# Epoch: 261, Train Loss: 0.246, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.246
# Epoch: 265, Train Loss: 0.242, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.242
# Epoch: 269, Train Loss: 0.228, aug_loss_primal: 0.005, aug_loss_fixed_point: 0.228
# Epoch: 273, Train Loss: 0.250, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.250
# Epoch: 277, Train Loss: 0.247, aug_loss_primal: 0.005, aug_loss_fixed_point: 0.247
# Epoch: 281, Train Loss: 0.247, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.247
# Epoch: 285, Train Loss: 0.246, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.246
# Epoch: 289, Train Loss: 0.246, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.246
# Epoch: 293, Train Loss: 0.236, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.236
# Epoch: 297, Train Loss: 0.238, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.238
# Epoch: 301, Train Loss: 0.203, aug_loss_primal: 0.003, aug_loss_fixed_point: 0.203
# Epoch: 305, Train Loss: 0.247, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.247
# Epoch: 309, Train Loss: 0.242, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.242
# Epoch: 313, Train Loss: 0.249, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.249
# Epoch: 317, Train Loss: 0.238, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.238
# Epoch: 321, Train Loss: 0.248, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.248
# Epoch: 325, Train Loss: 0.250, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.250
# Epoch: 329, Train Loss: 0.235, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.235
# Epoch: 333, Train Loss: 0.237, aug_loss_primal: 0.004, aug_loss_fixed_point: 0.237
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[7], line 45
#
#      41 x_obs = closest_obs[:, 0:num_obs]
#
#      42 y_obs = closest_obs[:, num_obs:2*num_obs]
#
# ---> 45 primal_sol, accumulated_res_primal, accumulated_res_fixed_point = model(inp, init_state_ego, param_des, pcd_data,  closest_obs, psi_obs, dim_x_obs, dim_y_obs,  y_ub, y_lb, P_diag, Pddot_diag, pcd_mean, pcd_std, goal_des)
#
#      46 loss, primal_loss, fixed_point_loss = model.ss_loss(accumulated_res_primal, primal_sol, accumulated_res_fixed_point)
#
#      48 optimizer.zero_grad()
#
#
#
# File ~/amith/torch_jax_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
#    1738 else:
#
# -> 1739     return self._call_impl(*args, **kwargs)
#
#
#
# File ~/amith/torch_jax_env/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1746 # this function, and just call forward.
#
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1750     return forward_call(*args, **kwargs)
#
#    1752 result = None
#
#    1753 called_always_called_hooks = set()
#
#
#
# File ~/Learned_QCQP/training_scripts/models/learned_optim_qcqp_3.py:771, in Learned_QCQP.forward(self, inp, init_state_ego, param_des, pcd_data, closest_obs, psi_obs, dim_x_obs, dim_y_obs, y_ub, y_lb, P_diag, Pddot_diag, pcd_mean, pcd_std, goal_des)
#
#     766 pcd_scaled = (pcd_data - self.min_pcd) / (self.max_pcd - self.min_pcd)
#
#     768 # pcd_scaled = (pcd_data - pcd_mean) / (self.max_pcd - pcd_std)
#
#     769
#
#     770 # Decode y
#
# --> 771 primal_sol, accumulated_res_primal, accumulated_res_fixed_point, res_primal_stack, res_fixed_point_stack = self.decoder_function(inp_norm, init_state_ego, pcd_scaled, x_obs_circle_traj, y_obs_circle_traj, a_obs, b_obs, y_ub, y_lb, param_des, goal_des)
#
#     773 # predict_traj = (P_diag @ primal_sol.T).T
#
#     774 # predict_acc = (Pddot_diag @ primal_sol.T).T
#
#     776 return primal_sol, accumulated_res_primal, accumulated_res_fixed_point
#
#
#
# File ~/Learned_QCQP/training_scripts/models/learned_optim_qcqp_3.py:738, in Learned_QCQP.decoder_function(self, inp_norm, init_state_ego, pcd_scaled, x_obs_circle_traj, y_obs_circle_traj, a_obs, b_obs, y_ub, y_lb, param_des, goal_des)
#
#     735 h_0 = self.gru_hidden_state_init(inp_features)
#
#     736 h_0_primal = self.gru_hidden_state_init(inp_features)
#
# --> 738 primal_sol, accumulated_res_primal, accumulated_res_fixed_point, res_primal_stack, res_fixed_point_stack =  self.custom_forward(init_state_ego, x_obs_circle_traj, y_obs_circle_traj, a_obs, b_obs, y_ub, y_lb, goal_des, c_x_guess, c_y_guess, h_0, lamda_x_init, lamda_y_init, h_0_primal)
#
#     740 return primal_sol, accumulated_res_primal, accumulated_res_fixed_point, res_primal_stack, res_fixed_point_stack
#
#
#
# File ~/Learned_QCQP/training_scripts/models/learned_optim_qcqp_3.py:651, in Learned_QCQP.custom_forward(self, init_state_ego, x_obs_circle_traj, y_obs_circle_traj, a_obs, b_obs, y_ub, y_lb, goal_des, c_x_guess, c_y_guess, h_0, lamda_x, lamda_y, h_0_primal)
#
#     647 lamda_prev = torch.hstack(( lamda_x_prev, lamda_y_prev  ))
#
#     650 alpha_a, d_a, lamda_x, lamda_y, alpha_v, d_v, alpha_obs, d_obs, s_lane, res_norm_batch = self.compute_alpha_d(primal_sol, x_obs_circle_traj, y_obs_circle_traj, y_ub, y_lb, a_obs, b_obs, lamda_x, lamda_y)
#
# --> 651 lamda = torch.hstack(( lamda_x, lamda_y  ))
#
#     653 r_lamda = torch.hstack((lamda_prev, lamda, lamda-lamda_prev   ))
#
#     654 gru_output, h = self.gru_context(r_lamda, h)
#
#
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), './weights/opt_surrogate_obs_avoidance_gru_new.pth')
